# %% [markdown]
# <a href="https://colab.research.google.com/github/harrietspence/harrietspence.github.io/blob/main/P_income_US_tidy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('BEA_income_percapita2.csv')
df
# Out:
#              State   2014   2015   2016   2017   2018   2019   2020
# 0          Alabama  37055  38531  39014  40223  41539  43288  46179
# 1           Alaska  55867  57575  56278  57189  59618  61316  62756
# 2          Arizona  38756  40334  41473  43497  45466  48124  52327
# 3         Arkansas  38749  39968  40873  41890  43384  44324  47154
# 4       California  51266  54546  56560  58804  61508  64919  70647
# 5         Colorado  50797  52339  52390  55251  58453  62124  65358
# 6      Connecticut  65498  67321  68680  70011  72926  75533  78463
# 7         Delaware  46015  47868  48734  50417  52716  54217  56324
# 8          Florida  43516  45659  46454  49055  51520  54560  57292
# 9          Georgia  39969  41941  43033  44993  46855  49083  51987
# 10          Hawaii  46044  47777  49122  51114  52164  54700  57241
# 11           Idaho  37680  39386  40098  41457  43217  45924  49491
# 12        Illinois  49238  51443  52036  53611  56536  58438  62139
# ...

# %%
df.head(2)
# Out:
#      State   2014   2015   2016   2017   2018   2019   2020
# 0  Alabama  37055  38531  39014  40223  41539  43288  46179
# 1   Alaska  55867  57575  56278  57189  59618  61316  62756

# %%
df2 = df.set_index(['State']).stack().reset_index()
df2
# Out:
#        State level_1      0
# 0    Alabama    2014  37055
# 1    Alabama    2015  38531
# 2    Alabama    2016  39014
# 3    Alabama    2017  40223
# 4    Alabama    2018  41539
# ..       ...     ...    ...
# 345  Wyoming    2016  54827
# 346  Wyoming    2017  57184
# 347  Wyoming    2018  60472
# 348  Wyoming    2019  64117
# 349  Wyoming    2020  65782
#
# [350 rows x 3 columns]

# %%
df2.columns
# Out:
# Index(['State', 'level_1', 0], dtype='object')

# %%
df3 = df2.rename(columns={'level_1':'Year', 0:'Per capita personal income'})
df3
# Out:
#        State  Year  Per capita personal income
# 0    Alabama  2014                       37055
# 1    Alabama  2015                       38531
# 2    Alabama  2016                       39014
# 3    Alabama  2017                       40223
# 4    Alabama  2018                       41539
# ..       ...   ...                         ...
# 345  Wyoming  2016                       54827
# 346  Wyoming  2017                       57184
# 347  Wyoming  2018                       60472
# 348  Wyoming  2019                       64117
# 349  Wyoming  2020                       65782
#
# [350 rows x 3 columns]

# %%
df3.tail(5)
# Out:
#        State  Year  Per capita personal income
# 345  Wyoming  2016                       54827
# 346  Wyoming  2017                       57184
# 347  Wyoming  2018                       60472
# 348  Wyoming  2019                       64117
# 349  Wyoming  2020                       65782

# %%
from google.colab import files
df3.to_csv('P_income_US_tidy.csv') 
files.download('P_income_US_tidy.csv')

# %%
df4 = pd.read_csv('firearm_rate_states.csv')
df4
# Out:
#        State  Year  Firearm Mortality rate
# 0    Alabama  2020                    23.6
# 1    Alabama  2019                    22.2
# 2    Alabama  2018                    21.8
# 3    Alabama  2017                    22.9
# 4    Alabama  2016                    21.5
# ..       ...   ...                     ...
# 345  Wyoming  2018                    21.5
# 346  Wyoming  2017                    18.8
# 347  Wyoming  2016                    17.4
# 348  Wyoming  2015                    19.6
# 349  Wyoming  2014                    16.2
#
# [350 rows x 3 columns]

# %%
df3.head(10)
# Out:
#      State  Year  Per capita personal income
# 0  Alabama  2014                       37055
# 1  Alabama  2015                       38531
# 2  Alabama  2016                       39014
# 3  Alabama  2017                       40223
# 4  Alabama  2018                       41539
# 5  Alabama  2019                       43288
# 6  Alabama  2020                       46179
# 7   Alaska  2014                       55867
# 8   Alaska  2015                       57575
# 9   Alaska  2016                       56278

# %%
df4.head(10)
# Out:
#      State  Year  Firearm Mortality rate
# 0  Alabama  2020                    23.6
# 1  Alabama  2019                    22.2
# 2  Alabama  2018                    21.8
# 3  Alabama  2017                    22.9
# 4  Alabama  2016                    21.5
# 5  Alabama  2015                    19.6
# 6  Alabama  2014                    16.9
# 7   Alaska  2020                    23.5
# 8   Alaska  2019                    24.4
# 9   Alaska  2018                    21.0

# %%
test = df4.sort_values(['Year'], ascending=[False])
df4
# Out:
#        State  Year  Firearm Mortality rate
# 0    Alabama  2020                    23.6
# 1    Alabama  2019                    22.2
# 2    Alabama  2018                    21.8
# 3    Alabama  2017                    22.9
# 4    Alabama  2016                    21.5
# ..       ...   ...                     ...
# 345  Wyoming  2018                    21.5
# 346  Wyoming  2017                    18.8
# 347  Wyoming  2016                    17.4
# 348  Wyoming  2015                    19.6
# 349  Wyoming  2014                    16.2
#
# [350 rows x 3 columns]

# %% [markdown]
# Merge the two tables, matching up the State and the year with income and firemarms rate

# %% [markdown]
# df5 = pd.concat([df3, df4])
# df5

# %%
extracted_col = df4["Firearm Mortality rate"]

# %%
df5 = df3.join(extracted_col)

# %%
df5.head(20)
# Out:
#       State  Year  Per capita personal income  Firearm Mortality rate
# 0   Alabama  2014                       37055                    23.6
# 1   Alabama  2015                       38531                    22.2
# 2   Alabama  2016                       39014                    21.8
# 3   Alabama  2017                       40223                    22.9
# 4   Alabama  2018                       41539                    21.5
# 5   Alabama  2019                       43288                    19.6
# 6   Alabama  2020                       46179                    16.9
# 7    Alaska  2014                       55867                    23.5
# 8    Alaska  2015                       57575                    24.4
# 9    Alaska  2016                       56278                    21.0
# 10   Alaska  2017                       57189                    24.5
# 11   Alaska  2018                       59618                    23.3
# ...

# %%
from google.colab import files
df5.to_csv('US_income_firearm.csv') 
files.download('US_income_firearm.csv')
