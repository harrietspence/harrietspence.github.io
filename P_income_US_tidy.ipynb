# %% [markdown]
# <a href="https://colab.research.google.com/github/harrietspence/harrietspence.github.io/blob/main/P_income_US_tidy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('BEA_income_percapita2.csv')
df
# Out:
#              State   2005   2006   2007   2008   2009   2010   2011   2012  \
# 0    United States  35868  38120  39883  41026  39356  40683  42747  44548
# 1          Alabama  29949  31474  32739  33583  32769  33946  35010  35824
# 2           Alaska  39075  41157  43906  47869  47258  49652  52569  53708
# 3          Arizona  32327  34703  35872  35748  33524  33876  35321  36545
# 4         Arkansas  28227  29617  31303  32306  31472  32372  34279  36582
# 5       California  38932  41746  43385  43567  41689  43246  45557  48121
# 6         Colorado  37797  40137  42074  42953  40093  40790  43658  45630
# 7      Connecticut  49738  53696  57684  60970  59684  61743  63132  64121
# 8         Delaware  39370  41053  41733  40894  40856  40942  43962  44070
# 9          Florida  35999  38386  39594  39401  36818  38872  40517  41540
# 10         Georgia  33445  34791  35680  35438  34274  34829  36842  37495
# ...

# %%
df.head(2)
# Out:
#            State   2005   2006   2007   2008   2009   2010   2011   2012  \
# 0  United States  35868  38120  39883  41026  39356  40683  42747  44548
# 1        Alabama  29949  31474  32739  33583  32769  33946  35010  35824
#
#     2013   2014   2015   2016   2017   2018   2019   2020   2021
# 0  44798  46887  48725  49613  51550  53786  56250  59765  64143
# 1  36014  37055  38531  39014  40223  41539  43288  46179  49769

# %%
df2 = df.set_index(['State']).stack().reset_index()
df2
# Out:
#              State level_1      0
# 0    United States    2005  35868
# 1    United States    2006  38120
# 2    United States    2007  39883
# 3    United States    2008  41026
# 4    United States    2009  39356
# ..             ...     ...    ...
# 862        Wyoming    2017  57184
# 863        Wyoming    2018  60472
# 864        Wyoming    2019  64117
# 865        Wyoming    2020  65782
# 866        Wyoming    2021  69666
#
# [867 rows x 3 columns]

# %%
df2.columns
# Out:
# Index(['State', 'level_1', 0], dtype='object')

# %%
df3 = df2.rename(columns={'level_2':'Year', 0:'Per capita personal income'})
df3
# Out:
#              State level_1  Per capita personal income
# 0    United States    2005                       35868
# 1    United States    2006                       38120
# 2    United States    2007                       39883
# 3    United States    2008                       41026
# 4    United States    2009                       39356
# ..             ...     ...                         ...
# 862        Wyoming    2017                       57184
# 863        Wyoming    2018                       60472
# 864        Wyoming    2019                       64117
# 865        Wyoming    2020                       65782
# 866        Wyoming    2021                       69666
#
# [867 rows x 3 columns]

# %%
from google.colab import files
df3.to_csv('P_income_US_tidy.csv') 
files.download('P_income_US_tidy.csv')
